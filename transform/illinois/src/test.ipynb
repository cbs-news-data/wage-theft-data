# %%
import pandas as pd

# %%
df = pd.read_excel("../input/FOIA-MWOT_final.xlsx")

# %%
df
# Out:
#      Filing Date                                      Employer     Status  \
# 0     2022-10-03                              Big star transit       Open
# 1     2022-10-03  Parker Cromwell (Home and Hearth Caregivers)       Open
# 2     2022-10-02                       Charlie’s Doghouse Inc.       Open
# 3     2022-10-02                                     MUDZI INC       Open
# 4     2022-10-02                                     MUDZI INC       Open
# ...          ...                                           ...        ...
# 3391  2017-01-05                                 Casting House       Paid
# 3392  2017-01-05                       R Vari & Associates LLC       Paid
# 3393  2017-01-05                    Twin Cleaning Professional  Dismissed
# 3394  2017-01-05                          MnAlan Trucking Corp  Dismissed
# 3395  2017-01-05       Rock Island Economic Growth Corporation  Dismissed
#
#       TotalAmountClaimed
# 0                    0.0
# 1                    4.0
# ...
