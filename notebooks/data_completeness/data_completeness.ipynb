# %% [markdown]
#  # Data completeness

# %% [markdown]
#  ## Contents
#  - [Overall data completeness](#complete-dataset)
#  - States that provided data
#    - [Minnesota](#Minnesota)
#    - [Rhode Island](#Rhode-Island)
#    - [Ohio](#Ohio)
#    - [Utah](#Utah)
#    - [Kansas](#Kansas)
#    - [Colorado](#Colorado)
#    - [Montana](#Montana)
#    - [Massachusetts](#Massachusetts)
#    - [Nebraska](#Nebraska)
#    - [Maine](#Maine)
#    - [Maryland](#Maryland)
#    - [California](#California)
#    - [Indiana](#Indiana)
#    - [New Jersey](#New-Jersey)
#    - [Wyoming](#Wyoming)
#    - [New York](#New-York)
#    - [Texas](#Texas)
#    - [West Virginia](#West-Virginia)
#    - [Kentucky](#Kentucky)
#    - [Washington](#Washington)
#    - [New Hampshire](#New-Hampshire)
#    - [Iowa](#Iowa)
#    - [Wisconsin](#Wisconsin)
#    - [South Carolina](#South-Carolina)
#    - [Illinois](#Illinois)

# %% [markdown]
#  ## Data import

# %%
import missingno as msno
import pandas as pd

# %%
df = pd.read_csv("input/state_complaints.csv.gz", low_memory=False)

# %% [markdown]
#  ## Complete dataset

# %%
msno.bar(df)
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ## States

# %% [markdown]
#  ### Minnesota

# %%
msno.bar(df.query("state_name == 'Minnesota'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Rhode Island

# %%
msno.bar(df.query("state_name == 'Rhode Island'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Ohio

# %%
msno.bar(df.query("state_name == 'Ohio'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Utah

# %%
msno.bar(df.query("state_name == 'Utah'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Kansas

# %%
msno.bar(df.query("state_name == 'Kansas'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Colorado

# %%
msno.bar(df.query("state_name == 'Colorado'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Montana

# %%
msno.bar(df.query("state_name == 'Montana'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Massachusetts

# %%
msno.bar(df.query("state_name == 'Massachusetts'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Nebraska

# %%
msno.bar(df.query("state_name == 'Nebraska'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Maine

# %%
msno.bar(df.query("state_name == 'Maine'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Maryland

# %%
msno.bar(df.query("state_name == 'Maryland'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### California

# %%
msno.bar(df.query("state_name == 'California'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Indiana

# %%
msno.bar(df.query("state_name == 'Indiana'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### New Jersey

# %%
msno.bar(df.query("state_name == 'New Jersey'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Wyoming

# %%
msno.bar(df.query("state_name == 'Wyoming'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### New York

# %%
msno.bar(df.query("state_name == 'New York'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Texas

# %%
msno.bar(df.query("state_name == 'Texas'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### West Virginia

# %%
msno.bar(df.query("state_name == 'West Virginia'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Kentucky

# %%
msno.bar(df.query("state_name == 'Kentucky'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Washington

# %%
msno.bar(df.query("state_name == 'Washington'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### New Hampshire

# %%
msno.bar(df.query("state_name == 'New Hampshire'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Iowa

# %%
msno.bar(df.query("state_name == 'Iowa'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Wisconsin

# %%
msno.bar(df.query("state_name == 'Wisconsin'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### South Carolina

# %%
msno.bar(df.query("state_name == 'South Carolina'"))
# Out:
# <AxesSubplot: >

# %% [markdown]
#  ### Illinois

# %%
msno.bar(df.query("state_name == 'Illinois'"))
# Out:
# <AxesSubplot: >
